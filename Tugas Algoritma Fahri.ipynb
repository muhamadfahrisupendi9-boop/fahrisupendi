# %% [markdown]
# <a href="https://colab.research.google.com/github/muhamadfahrisupendi9-boop/fahrisupendi/blob/main/Tugas%20Algoritma%20Fahri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#input
total_hari = int(input("Masukkan jumlah hari: "))

#Input & Output
tahun = total_hari // 365
sisa_hari = total_hari % 365

bulan = sisa_hari // 30
hari = sisa_hari % 30

print("Hasil konversi:")
print(tahun, "tahun,", bulan, "bulan,", hari, "hari")

# %%
# input
batas = int(input("Masukkan batas angka (1-100): "))

# proses & output
for i in range(1, batas + 1):
    if i % 3 == 0 and i % 5 == 0:
        print("Fizzbuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)
